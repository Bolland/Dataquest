# %% [markdown]
# Over the next two missions, we'll dive into some of pandas' internals to better understand how it does things under the hood.
#
# The **three key data structures in pandas** are:
#
# * Series objects (collections of values)
# * DataFrames (collections of Series objects)
# * Panels (collections of DataFrame objects)
#
# ## Series
#
# **Series** objects use NumPy arrays for fast computation, but add valuable features to them for analyzing data. While NumPy arrays use an integer index, for example, Series objects can use **other index types**, such as a string index. Series objects also allow for **mixed data types**, and use the **NaN** Python value for handling missing values.

# %%
import pandas as pd

fandango = pd.read_csv('fandango_score_comparison.csv')
print(fandango.head(2))
# Out:
#                              FILM  RottenTomatoes  RottenTomatoes_User  \
# 0  Avengers: Age of Ultron (2015)              74                   86
# 1               Cinderella (2015)              85                   80
#
#    Metacritic  Metacritic_User  IMDB  Fandango_Stars  Fandango_Ratingvalue  \
# 0          66              7.1   7.8             5.0                   4.5
# 1          67              7.5   7.1             5.0                   4.5
#
#    RT_norm  RT_user_norm         ...           IMDB_norm  RT_norm_round  \
# 0     3.70           4.3         ...                3.90            3.5
# 1     4.25           4.0         ...                3.55            4.5
#
#    RT_user_norm_round  Metacritic_norm_round  Metacritic_user_norm_round  \
# 0                 4.5                    3.5                         3.5
# 1                 4.0                    3.5                         4.0
#
#    IMDB_norm_round  Metacritic_user_vote_count  IMDB_user_vote_count  \
# 0              4.0                        1330                271107
# 1              3.5                         249                 65709
#
#    Fandango_votes  Fandango_Difference
# 0           14846                  0.5
# 1           12640                  0.5
#
# [2 rows x 22 columns]

# %%
series_film = fandango['FILM']
print(series_film.head(5))


series_rt = fandango['RottenTomatoes']
print(series_rt.head(5))
# Out:
# 0    Avengers: Age of Ultron (2015)
# 1                 Cinderella (2015)
# 2                    Ant-Man (2015)
# 3            Do You Believe? (2015)
# 4     Hot Tub Time Machine 2 (2015)
# Name: FILM, dtype: object
# 0    74
# 1    85
# 2    80
# 3    18
# 4    14
# Name: RottenTomatoes, dtype: int64

# %% [markdown]
# Both of these Series objects **use the same integer indexes**. This means that the value at index 5, for example, would describe the same film in both Series objects (The Water Diviner (2015)). To look up information about a specific movie, we would need to know its integer index.
#
# If we only had these two Series objects and wanted to look up the Rotten Tomatoes scores for *Minions (2015)* and *Leviathan (2014)*, we'd have to:
#
# * Find the integer index corresponding to Minions (2015) in series_film
# * Look up the value at that integer index from series_rt
# * Find the integer index corresponding to Leviathan (2014) in series_film
# * Look up the value at that integer index from series_rt
#
# This becomes especially cumbersome as we scale up the problem to look for a larger number of movies. What we really want is a way to retrieve the Rotten Tomatoes scores for many movies at the same time with just one command (and one Series object). To accomplish this, we need to move away from using integer indexes, and use string indexes corresponding to the film names instead. Then we can pass in a list of strings matching the film names to retrieve the scores, like so:
#
# `series_custom[['Minions (2015)', 'Leviathan (2014)']]`
#
# ### Exercise:
# Create a **new Series object** named series_custom that has a string index (based on the values from film_names), and contains all of the Rotten Tomatoes scores from

# %%
film_names = series_film.values
rt_scores = series_rt.values

series_custom = pd.Series(data = rt_scores, index = film_names)

print(series_custom.head(5))
# Out:
# Avengers: Age of Ultron (2015)    74
# Cinderella (2015)                 85
# Ant-Man (2015)                    80
# Do You Believe? (2015)            18
# Hot Tub Time Machine 2 (2015)     14
# dtype: int64

# %% [markdown]
# Even though we specified that the Series object uses a custom string index, the **object still has an internal integer index that we can use for selection** (Difference to dictionaries!). When it comes to indexes, **Series objects act like both dictionaries and lists**. We can access values with our custom index (like the keys in a dictionary), or the integer index (like the index in a list).

# %%
# Use string index like a dictionary with [[ ... ]]
print(series_custom[['Minions (2015)', 'Leviathan (2014)']])

# Use int index with [ ... ]
print(series_custom[5:11])
# Out:
# Minions (2015)      54
# Leviathan (2014)    99
# dtype: int64
# The Water Diviner (2015)             63
# Irrational Man (2015)                42
# Top Five (2014)                      86
# Shaun the Sheep Movie (2015)         99
# Love & Mercy (2015)                  89
# Far From The Madding Crowd (2015)    84
# dtype: int64

# %% [markdown]
# **Reindexing** is the pandas way of modifying the alignment between labels (indexes) and the data (values). The `reindex()` method allows us to specify a different order for the labels (indexes) in a Series object. This method takes in a list of strings corresponding to the order we'd like for that Series object.

# %%
original_index = series_custom.index
sorted_index = sorted(original_index)
#print(sorted_index)
sorted_by_index = series_custom.reindex(sorted(original_index))

# %% [markdown]
# To make sorting easier, pandas comes with a `sort_index()` method that **sorts a Series by index**, and a `sort_values()` method that **sorts a Series by its values**.

# %%
sc2 = series_custom.sort_index()
sc3 = series_custom.sort_values()
print(sc2.head(10))
print(sc3.head(10))
# Out:
# '71 (2015)                    97
# 5 Flights Up (2015)           52
# A Little Chaos (2015)         40
# A Most Violent Year (2014)    90
# About Elly (2015)             97
# Aloha (2015)                  19
# American Sniper (2015)        72
# American Ultra (2015)         46
# Amy (2015)                    97
# Annie (2014)                  27
# dtype: int64
# Paul Blart: Mall Cop 2 (2015)     5
# Hitman: Agent 47 (2015)           7
# Hot Pursuit (2015)                8
# Fantastic Four (2015)             9
# Taken 3 (2015)                    9
# The Boy Next Door (2015)         10
# The Loft (2015)                  11
# Unfinished Business (2015)       11
# Mortdecai (2015)                 12
# Seventh Son (2015)               12
# dtype: int64

# %% [markdown]
# ### Vector operations
# Since **pandas builds on NumPy**, it takes advantage of **NumPy's vectorizaton capabilities**. These capabilities generate incredibly optimized, low level code in the C programming language to loop over the values. Using a traditional for loop would be much slower, especially for large data sets.
#
# We can use any of the standard Python arithmetic operators (+, -, *, and /) to transform each of the values in a Series object. If we wanted to transform the Rotten Tomatoes scores from a 100-point scale to a 10-point scale, for example, we could use the Python division operator (/) to divide the Series by 10. We can even use NumPy functions to transform and run calculations over Series objects:

# %%
import numpy as np

# devide all entreis by 10
series_custom/10

# Add each value with each other
np.add(series_custom, series_custom)
# Apply sine function to each value
np.sin(series_custom)
# Return the highest value (will return a single value, not a Series)
np.max(series_custom)

print(sc3[len(sc3)-10:])
# Out:
# Paddington (2015)                             98
# Mr. Turner (2014)                             98
# Timbuktu (2015)                               99
# Shaun the Sheep Movie (2015)                  99
# Leviathan (2014)                              99
# Song of the Sea (2014)                        99
# Phoenix (2015)                                99
# Selma (2014)                                  99
# Seymour: An Introduction (2015)              100
# Gett: The Trial of Viviane Amsalem (2015)    100
# dtype: int64

# %% [markdown]
# ### Series vs. ndarray
# The values in a **Series object are part of an ndarray**, the core data type in NumPy. Applying some NumPy functions to a Series object will **return a new Series object**, while other functions will return a single value. NumPy's documentation (http://docs.scipy.org/doc/numpy/reference/generated/numpy.sin.html#numpy.sin) gives us a good sense of the return value for each function. If a particular NumPy function **usually returns an ndarray**, it will return a **Series object** instead when we **apply it to a Series.**
#
# ### Pandas and vectorized operations
#
# Pandas uses **vectorized operations** for many tasks, such as filtering values within a single Series object and comparing two different Series objects. For example, to find all films with an average critic rating of 50 or above on Rotten Tomatoes, running:
#
# `series_custom > 50`
#
# will actually **return a Series object with a Boolean value for each film**. That's because pandas applies the filter (> 50) to each value in the Series object. To retrieve the actual film names, we need to pass this Boolean series into the original Series object.

# %%
series_greater_than_50 = series_custom[series_custom > 50]
print(series_greater_than_50.shape[0])
print(series_custom.shape[0])
print('Ratio of movies greater 50:')
print(series_greater_than_50.shape[0]/series_custom.shape[0])
# Out:
# 94
# 146
# Ratio of movies greater 50:
# 0.6438356164383562

# %%
# Combining boolean criteria with '&', '|'

bigger_50 = series_custom > 50
smaller_55 = series_custom <55

between_50_55 = series_custom[bigger_50 & smaller_55]
print(between_50_55)
# Out:
# Unbroken (2014)                  51
# 5 Flights Up (2015)              52
# Saint Laurent (2015)             51
# The Age of Adaline (2015)        54
# Maggie (2015)                    54
# Escobar: Paradise Lost (2015)    52
# Woman in Gold (2015)             52
# Minions (2015)                   54
# Spare Parts (2015)               52
# dtype: int64

# %%
rt_critics = pd.Series(fandango['RottenTomatoes'].values, index=fandango['FILM'])
rt_users = pd.Series(fandango['RottenTomatoes_User'].values, index=fandango['FILM'])


rt_mean = pd.Series((rt_critics+rt_users)/2)
print(rt_mean[:10])
# Out:
# FILM
# Avengers: Age of Ultron (2015)    80.0
# Cinderella (2015)                 82.5
# Ant-Man (2015)                    85.0
# Do You Believe? (2015)            51.0
# Hot Tub Time Machine 2 (2015)     21.0
# The Water Diviner (2015)          62.5
# Irrational Man (2015)             47.5
# Top Five (2014)                   75.0
# Shaun the Sheep Movie (2015)      90.5
# Love & Mercy (2015)               88.0
# dtype: float64

# %% [markdown]
# ## DataFrames
#
# **DataFrames** use Series objects to represent columns. Dataframe objects can easily query and interact with many columns. When we select a single column from a DataFrame, pandas will return the **Series object representing that column**. By default, pandas indexes each individual Series object in a DataFrame with the **integer data type**. Each value in the Series has a unique integer index, or position. Like most Python data structures, the Series object uses 0-indexing. The **indexing ranges from 0 to n-1**, where n is the number of rows. We can use an integer index to select an individual value in a Series if we know its position.
#
# **Series** objects maintain **data alignment between values and their index labels**. Because dataframes are basically collections of Series objects, they maintain **alignment along both columns and rows**.
#
# Whenever you call a method that returns or prints a dataframe, the **index values** (such as a sequence of integers) appear in the **leftmost column**. You can also use the `index` attribute to access the index values directly.

# %%
print('First two rows:')
print(fandango.head(2))

print('Index:')
print(fandango.index)
# Out:
# First two rows:
#                              FILM  RottenTomatoes  RottenTomatoes_User  \
# 0  Avengers: Age of Ultron (2015)              74                   86
# 1               Cinderella (2015)              85                   80
#
#    Metacritic  Metacritic_User  IMDB  Fandango_Stars  Fandango_Ratingvalue  \
# 0          66              7.1   7.8             5.0                   4.5
# 1          67              7.5   7.1             5.0                   4.5
#
#    RT_norm  RT_user_norm         ...           IMDB_norm  RT_norm_round  \
# 0     3.70           4.3         ...                3.90            3.5
# 1     4.25           4.0         ...                3.55            4.5
#
#    RT_user_norm_round  Metacritic_norm_round  Metacritic_user_norm_round  \
# 0                 4.5                    3.5                         3.5
# 1                 4.0                    3.5                         4.0
#
#    IMDB_norm_round  Metacritic_user_vote_count  IMDB_user_vote_count  \
# 0              4.0                        1330                271107
# 1              3.5                         249                 65709
#
#    Fandango_votes  Fandango_Difference
# 0           14846                  0.5
# 1           12640                  0.5
#
# [2 rows x 22 columns]
# Index:
# RangeIndex(start=0, stop=146, step=1)

# %%
print(fandango.index[39])

print(fandango.iloc[39])
# Out:
# 39
# FILM                          Maps to the Stars (2015)
# RottenTomatoes                                      60
# RottenTomatoes_User                                 46
# Metacritic                                          67
# Metacritic_User                                    5.8
# IMDB                                               6.3
# Fandango_Stars                                     3.5
# Fandango_Ratingvalue                               3.1
# RT_norm                                              3
# RT_user_norm                                       2.3
# Metacritic_norm                                   3.35
# Metacritic_user_nom                                2.9
# IMDB_norm                                         3.15
# RT_norm_round                                        3
# RT_user_norm_round                                 2.5
# Metacritic_norm_round                              3.5
# Metacritic_user_norm_round                           3
# IMDB_norm_round                                      3
# Metacritic_user_vote_count                          46
# IMDB_user_vote_count                             22440
# Fandango_votes                                      35
# Fandango_Difference                                0.4
# Name: 39, dtype: object

# %% [markdown]
# With **Series**, each unique index value refers to a data value. With **dataframes**, however, each index value refers to an entire row. We can use the integer index to select rows in a few different ways:

# %%
# First five rows
fandango[0:5]
# From row at 140 and higher
fandango[140:]
# Just row at index 50 --> needs iloc!
fandango.iloc[50]
# Just row at index 45 and 90
fandango.iloc[[45,90]]
# Out:
#                                                FILM  RottenTomatoes  \
# 45                              Tomorrowland (2015)              50
# 90  The SpongeBob Movie: Sponge Out of Water (2015)              78
#
#     RottenTomatoes_User  Metacritic  Metacritic_User  IMDB  Fandango_Stars  \
# 45                   53          60              6.4   6.6             4.0
# 90                   55          62              6.5   6.1             3.5
#
#     Fandango_Ratingvalue  RT_norm  RT_user_norm         ...           \
# 45                   3.7      2.5          2.65         ...
# 90                   3.3      3.9          2.75         ...
#
#     IMDB_norm  RT_norm_round  RT_user_norm_round  Metacritic_norm_round  \
# 45       3.30            2.5                 2.5                    3.0
# 90       3.05            4.0                 3.0                    3.0
#
#     Metacritic_user_norm_round  IMDB_norm_round  Metacritic_user_vote_count  \
# 45                         3.0              3.5                         262
# 90                         3.5              3.0                         196
#
#     IMDB_user_vote_count  Fandango_votes  Fandango_Difference
# 45                 42937            8077                  0.3
# 90                 26046            4493                  0.2
#
# [2 rows x 22 columns]

# %% [markdown]
# ### iloc with dataframes
# We use **bracket notation** to select a slice (continuous sequence) of rows, just as we would for a list. To select an **individual row**, however, we'll need to use the **iloc[] method**. This method accepts the following objects for selection:
#
# * An integer
# * A list of integers
# * A slice object
# * A Boolean array
#
# When selecting an **individual row**, pandas will return a **Series** object. When selecting **multiple rows**, it will return a **subset of the original dataframe** as a new dataframe.

# %%
first_last = fandango.iloc[[0,len(fandango)-1]] # use double brackets!

# %% [markdown]
# ### Indexing Dataframes
#
# The dataframe object has a `set_index()` method that allows us to pass in the **name of the column** we want pandas to use as the Dataframe index. By default, pandas will **create a new dataframe**, index it by the values in the column we specify, then drop that column. The set_index() method has a **few parameters** that allow us to tweak this behavior:
#
# * `inplace`: If set to True, this parameter will **set the index for the current**, "live" dataframe, instead of returning a new dataframe.
# * `drop`: If set to False, this parameter will **keep the column we specified** as the index, instead of dropping it.

# %%
# Create new dataframes with "FILM" column as index and not being dropped.
fandango_films = fandango.set_index('FILM', drop = False, inplace = False)

print(fandango.shape)
print(fandango_films.shape)

print(fandango_films.iloc[[5,10]])
print(fandango_films.index)
# Out:
# (146, 22)
# (146, 22)
#                                                                 FILM  \
# FILM
# The Water Diviner (2015)                    The Water Diviner (2015)
# Far From The Madding Crowd (2015)  Far From The Madding Crowd (2015)
#
#                                    RottenTomatoes  RottenTomatoes_User  \
# FILM
# The Water Diviner (2015)                       63                   62
# Far From The Madding Crowd (2015)              84                   77
#
#                                    Metacritic  Metacritic_User  IMDB  \
# FILM
# The Water Diviner (2015)                   50              6.8   7.2
# Far From The Madding Crowd (2015)          71              7.5   7.2
#
#                                    Fandango_Stars  Fandango_Ratingvalue  \
# FILM
# The Water Diviner (2015)                      4.5                   4.0
# Far From The Madding Crowd (2015)             4.5                   4.0
#
#                                    RT_norm  RT_user_norm         ...           \
# FILM                                                             ...
# The Water Diviner (2015)              3.15          3.10         ...
# Far From The Madding Crowd (2015)     4.20          3.85         ...
#
#                                    IMDB_norm  RT_norm_round  \
# FILM
# The Water Diviner (2015)                 3.6            3.0
# Far From The Madding Crowd (2015)        3.6            4.0
#
#                                    RT_user_norm_round  Metacritic_norm_round  \
# FILM
# The Water Diviner (2015)                          3.0                    2.5
# Far From The Madding Crowd (2015)                 4.0                    3.5
#
#                                    Metacritic_user_norm_round  \
# FILM
# The Water Diviner (2015)                                  3.5
# Far From The Madding Crowd (2015)                         4.0
#
#                                    IMDB_norm_round  \
# FILM
# The Water Diviner (2015)                       3.5
# Far From The Madding Crowd (2015)              3.5
#
#                                    Metacritic_user_vote_count  \
# FILM
# The Water Diviner (2015)                                   34
# Far From The Madding Crowd (2015)                          35
#
#                                    IMDB_user_vote_count  Fandango_votes  \
# FILM
# The Water Diviner (2015)                          39373             397
# Far From The Madding Crowd (2015)                 12129             804
#
#                                    Fandango_Difference
# FILM
# The Water Diviner (2015)                           0.5
# Far From The Madding Crowd (2015)                  0.5
#
# [2 rows x 22 columns]
# Index(['Avengers: Age of Ultron (2015)', 'Cinderella (2015)', 'Ant-Man (2015)',
#        'Do You Believe? (2015)', 'Hot Tub Time Machine 2 (2015)',
#        'The Water Diviner (2015)', 'Irrational Man (2015)', 'Top Five (2014)',
#        'Shaun the Sheep Movie (2015)', 'Love & Mercy (2015)',
#        ...
#        'The Woman In Black 2 Angel of Death (2015)', 'Danny Collins (2015)',
#        'Spare Parts (2015)', 'Serena (2015)', 'Inside Out (2015)',
#        'Mr. Holmes (2015)', ''71 (2015)', 'Two Days, One Night (2014)',
#        'Gett: The Trial of Viviane Amsalem (2015)',
#        'Kumiko, The Treasure Hunter (2015)'],
#       dtype='object', name='FILM', length=146)

# %% [markdown]
# Now that we have a custom index, we can **select a row by film name instead of row number** (which is the default integer index). We can select rows using the custom index by either:
#
# * Using the **loc[] method** (the same way we would the iloc[] method)
# * Creating a slice using **bracket notation**

# %%
# Slice using either bracket notation or loc[]
fandango_films["Avengers: Age of Ultron (2015)":"Hot Tub Time Machine 2 (2015)"]
fandango_films.loc["Avengers: Age of Ultron (2015)":"Hot Tub Time Machine 2 (2015)"]

# Specific movie
fandango_films.loc['Kumiko, The Treasure Hunter (2015)']

# Selecting list of movies
fandango_films.loc[['Kumiko, The Treasure Hunter (2015)', 'Do You Believe? (2015)', 'Ant-Man (2015)']]

#fandango_films.iloc[5]
# Out:
#                                                                   FILM  \
# FILM
# Kumiko, The Treasure Hunter (2015)  Kumiko, The Treasure Hunter (2015)
# Do You Believe? (2015)                          Do You Believe? (2015)
# Ant-Man (2015)                                          Ant-Man (2015)
#
#                                     RottenTomatoes  RottenTomatoes_User  \
# FILM
# Kumiko, The Treasure Hunter (2015)              87                   63
# Do You Believe? (2015)                          18                   84
# Ant-Man (2015)                                  80                   90
#
#                                     Metacritic  Metacritic_User  IMDB  \
# FILM
# Kumiko, The Treasure Hunter (2015)          68              6.4   6.7
# Do You Believe? (2015)                      22              4.7   5.4
# Ant-Man (2015)                              64              8.1   7.8
#
#                                     Fandango_Stars  Fandango_Ratingvalue  \
# FILM
# Kumiko, The Treasure Hunter (2015)             3.5                   3.5
# Do You Believe? (2015)                         5.0                   4.5
# Ant-Man (2015)                                 5.0                   4.5
#
#                                     RT_norm  RT_user_norm  \
# FILM
# Kumiko, The Treasure Hunter (2015)     4.35          3.15
# Do You Believe? (2015)                 0.90          4.20
# Ant-Man (2015)                         4.00          4.50
#
#                                            ...           IMDB_norm  \
# FILM                                       ...
# Kumiko, The Treasure Hunter (2015)         ...                3.35
# Do You Believe? (2015)                     ...                2.70
# Ant-Man (2015)                             ...                3.90
#
#                                     RT_norm_round  RT_user_norm_round  \
# FILM
# Kumiko, The Treasure Hunter (2015)            4.5                 3.0
# Do You Believe? (2015)                        1.0                 4.0
# Ant-Man (2015)                                4.0                 4.5
#
#                                     Metacritic_norm_round  \
# FILM
# Kumiko, The Treasure Hunter (2015)                    3.5
# Do You Believe? (2015)                                1.0
# Ant-Man (2015)                                        3.0
#
#                                     Metacritic_user_norm_round  \
# FILM
# Kumiko, The Treasure Hunter (2015)                         3.0
# Do You Believe? (2015)                                     2.5
# Ant-Man (2015)                                             4.0
#
#                                     IMDB_norm_round  \
# FILM
# Kumiko, The Treasure Hunter (2015)              3.5
# Do You Believe? (2015)                          2.5
# Ant-Man (2015)                                  4.0
#
#                                     Metacritic_user_vote_count  \
# FILM
# Kumiko, The Treasure Hunter (2015)                          19
# Do You Believe? (2015)                                      31
# Ant-Man (2015)                                             627
#
#                                     IMDB_user_vote_count  Fandango_votes  \
# FILM
# Kumiko, The Treasure Hunter (2015)                  5289              41
# Do You Believe? (2015)                              3136            1793
# Ant-Man (2015)                                    103660           12055
#
#                                     Fandango_Difference
# FILM
# Kumiko, The Treasure Hunter (2015)                  0.0
# Do You Believe? (2015)                              0.5
# Ant-Man (2015)                                      0.5
#
# [3 rows x 22 columns]

# %% [markdown]
# ### Apply to DataFrames
#
# Recall that a dataframe object represents both rows and columns as Series objects. The `apply()` method in pandas allows us to specify **Python logic** that we want to evaluate **over the Series objects in a dataframe** (row or column), e.g.
# * Calculate the standard deviations for each numeric column
# * Lowercase all film names in the FILM column
#
# The `apply()` method requires us to pass in the **vectorized operation** we want to apply over each Series object. The method runs **over the dataframe's columns by default**, but we can use the axis parameter to change this (which we'll do later). If the vectorized operation usually returns a single value it will return a Series object containing the computed value for each column. For example, in the following code, we use a lambda function to multiply each float column by 2:

# %%
import numpy as np

types = fandango_films.dtypes
#print(types.index)

float_columns = types[types.values == 'float64'].index

#print(float_columns)

# float_df contains only the float columns
float_df = fandango_films[float_columns]

float_df.apply(lambda x: np.sqrt(x)) 

#fandango_films
# usage of a lambda function
#float_df.apply(lambda x: x*2)
# Out:
#                                                 Metacritic_User      IMDB  \
# FILM
# Avengers: Age of Ultron (2015)                         2.664583  2.792848
# Cinderella (2015)                                      2.738613  2.664583
# Ant-Man (2015)                                         2.846050  2.792848
# Do You Believe? (2015)                                 2.167948  2.323790
# Hot Tub Time Machine 2 (2015)                          1.843909  2.258318
# The Water Diviner (2015)                               2.607681  2.683282
# Irrational Man (2015)                                  2.756810  2.626785
# Top Five (2014)                                        2.607681  2.549510
# Shaun the Sheep Movie (2015)                           2.966479  2.720294
# Love & Mercy (2015)                                    2.915476  2.792848
# Far From The Madding Crowd (2015)                      2.738613  2.683282
# Black Sea (2015)                                       2.569047  2.529822
# Leviathan (2014)                                       2.683282  2.774887
# Unbroken (2014)                                        2.549510  2.683282
# The Imitation Game (2014)                              2.863564  2.846050
# Taken 3 (2015)                                         2.144761  2.469818
# Ted 2 (2015)                                           2.549510  2.569047
# Southpaw (2015)                                        2.863564  2.792848
# Night at the Museum: Secret of the Tomb (2014)         2.408319  2.509980
# Pixels (2015)                                          2.302173  2.366432
# McFarland, USA (2015)                                  2.683282  2.738613
# Insidious: Chapter 3 (2015)                            2.626785  2.509980
# The Man From U.N.C.L.E. (2015)                         2.810694  2.756810
# Run All Night (2015)                                   2.701851  2.569047
# Trainwreck (2015)                                      2.449490  2.588436
# Selma (2014)                                           2.664583  2.738613
# Ex Machina (2015)                                      2.810694  2.774887
# Still Alice (2015)                                     2.792848  2.738613
# Wild Tales (2014)                                      2.966479  2.863564
# The End of the Tour (2015)                             2.738613  2.810694
# ...                                                         ...       ...
# Clouds of Sils Maria (2015)                            2.664583  2.607681
# Testament of Youth (2015)                              2.810694  2.701851
# Infinitely Polar Bear (2015)                           2.810694  2.683282
# Phoenix (2015)                                         2.828427  2.683282
# The Wolfpack (2015)                                    2.645751  2.664583
# The Stanford Prison Experiment (2015)                  2.915476  2.664583
# Tangerine (2015)                                       2.701851  2.720294
# Magic Mike XXL (2015)                                  2.323790  2.509980
# Home (2015)                                            2.701851  2.588436
# The Wedding Ringer (2015)                              1.816590  2.588436
# Woman in Gold (2015)                                   2.683282  2.720294
# The Last Five Years (2015)                             2.626785  2.449490
# Mission: Impossible â€“ Rogue Nation (2015)            2.828427  2.792848
# Amy (2015)                                             2.966479  2.828427
# Jurassic World (2015)                                  2.645751  2.701851
# Minions (2015)                                         2.387467  2.588436
# Max (2015)                                             2.428992  2.645751
# Paul Blart: Mall Cop 2 (2015)                          1.549193  2.073644
# The Longest Ride (2015)                                2.190890  2.683282
# The Lazarus Effect (2015)                              2.213594  2.280351
# The Woman In Black 2 Angel of Death (2015)             2.097618  2.213594
# Danny Collins (2015)                                   2.664583  2.664583
# Spare Parts (2015)                                     2.664583  2.683282
# Serena (2015)                                          2.302173  2.323790
# Inside Out (2015)                                      2.983287  2.932576
# Mr. Holmes (2015)                                      2.810694  2.720294
# '71 (2015)                                             2.738613  2.683282
# Two Days, One Night (2014)                             2.966479  2.720294
# Gett: The Trial of Viviane Amsalem (2015)              2.701851  2.792848
# Kumiko, The Treasure Hunter (2015)                     2.529822  2.588436
#
#                                                 Fandango_Stars  \
# FILM
# Avengers: Age of Ultron (2015)                        2.236068
# Cinderella (2015)                                     2.236068
# Ant-Man (2015)                                        2.236068
# Do You Believe? (2015)                                2.236068
# Hot Tub Time Machine 2 (2015)                         1.870829
# The Water Diviner (2015)                              2.121320
# Irrational Man (2015)                                 2.000000
# Top Five (2014)                                       2.000000
# Shaun the Sheep Movie (2015)                          2.121320
# Love & Mercy (2015)                                   2.121320
# Far From The Madding Crowd (2015)                     2.121320
# Black Sea (2015)                                      2.000000
# Leviathan (2014)                                      2.000000
# Unbroken (2014)                                       2.121320
# The Imitation Game (2014)                             2.236068
# Taken 3 (2015)                                        2.121320
# Ted 2 (2015)                                          2.121320
# Southpaw (2015)                                       2.236068
# Night at the Museum: Secret of the Tomb (2014)        2.121320
# Pixels (2015)                                         2.121320
# McFarland, USA (2015)                                 2.236068
# Insidious: Chapter 3 (2015)                           2.121320
# The Man From U.N.C.L.E. (2015)                        2.121320
# Run All Night (2015)                                  2.121320
# Trainwreck (2015)                                     2.121320
# Selma (2014)                                          2.236068
# Ex Machina (2015)                                     2.121320
# Still Alice (2015)                                    2.121320
# Wild Tales (2014)                                     2.121320
# The End of the Tour (2015)                            2.121320
# ...                                                        ...
# Clouds of Sils Maria (2015)                           1.870829
# Testament of Youth (2015)                             2.000000
# Infinitely Polar Bear (2015)                          2.000000
# Phoenix (2015)                                        1.870829
# The Wolfpack (2015)                                   1.870829
# The Stanford Prison Experiment (2015)                 2.000000
# Tangerine (2015)                                      2.000000
# Magic Mike XXL (2015)                                 2.121320
# Home (2015)                                           2.121320
# The Wedding Ringer (2015)                             2.121320
# Woman in Gold (2015)                                  2.121320
# The Last Five Years (2015)                            2.121320
# Mission: Impossible â€“ Rogue Nation (2015)           2.121320
# Amy (2015)                                            2.121320
# Jurassic World (2015)                                 2.121320
# Minions (2015)                                        2.000000
# Max (2015)                                            2.121320
# Paul Blart: Mall Cop 2 (2015)                         1.870829
# The Longest Ride (2015)                               2.121320
# The Lazarus Effect (2015)                             1.732051
# The Woman In Black 2 Angel of Death (2015)            1.732051
# Danny Collins (2015)                                  2.000000
# Spare Parts (2015)                                    2.121320
# Serena (2015)                                         1.732051
# Inside Out (2015)                                     2.121320
# Mr. Holmes (2015)                                     2.000000
# '71 (2015)                                            1.870829
# Two Days, One Night (2014)                            1.870829
# Gett: The Trial of Viviane Amsalem (2015)             1.870829
# Kumiko, The Treasure Hunter (2015)                    1.870829
#
#                                                 Fandango_Ratingvalue  \
# FILM
# Avengers: Age of Ultron (2015)                              2.121320
# Cinderella (2015)                                           2.121320
# Ant-Man (2015)                                              2.121320
# Do You Believe? (2015)                                      2.121320
# Hot Tub Time Machine 2 (2015)                               1.732051
# The Water Diviner (2015)                                    2.000000
# Irrational Man (2015)                                       1.870829
# Top Five (2014)                                             1.870829
# Shaun the Sheep Movie (2015)                                2.000000
# Love & Mercy (2015)                                         2.000000
# Far From The Madding Crowd (2015)                           2.000000
# Black Sea (2015)                                            1.870829
# Leviathan (2014)                                            1.870829
# Unbroken (2014)                                             2.024846
# The Imitation Game (2014)                                   2.144761
# Taken 3 (2015)                                              2.024846
# Ted 2 (2015)                                                2.024846
# Southpaw (2015)                                             2.144761
# Night at the Museum: Secret of the Tomb (2014)              2.024846
# Pixels (2015)                                               2.024846
# McFarland, USA (2015)                                       2.144761
# Insidious: Chapter 3 (2015)                                 2.024846
# The Man From U.N.C.L.E. (2015)                              2.024846
# Run All Night (2015)                                        2.024846
# Trainwreck (2015)                                           2.024846
# Selma (2014)                                                2.144761
# Ex Machina (2015)                                           2.024846
# Still Alice (2015)                                          2.024846
# Wild Tales (2014)                                           2.024846
# The End of the Tour (2015)                                  2.024846
# ...                                                              ...
# Clouds of Sils Maria (2015)                                 1.843909
# Testament of Youth (2015)                                   1.974842
# Infinitely Polar Bear (2015)                                1.974842
# Phoenix (2015)                                              1.843909
# The Wolfpack (2015)                                         1.843909
# The Stanford Prison Experiment (2015)                       1.974842
# Tangerine (2015)                                            1.974842
# Magic Mike XXL (2015)                                       2.097618
# Home (2015)                                                 2.097618
# The Wedding Ringer (2015)                                   2.097618
# Woman in Gold (2015)                                        2.097618
# The Last Five Years (2015)                                  2.097618
# Mission: Impossible â€“ Rogue Nation (2015)                 2.097618
# Amy (2015)                                                  2.097618
# Jurassic World (2015)                                       2.121320
# Minions (2015)                                              2.000000
# Max (2015)                                                  2.121320
# Paul Blart: Mall Cop 2 (2015)                               1.870829
# The Longest Ride (2015)                                     2.121320
# The Lazarus Effect (2015)                                   1.732051
# The Woman In Black 2 Angel of Death (2015)                  1.732051
# Danny Collins (2015)                                        2.000000
# Spare Parts (2015)                                          2.121320
# Serena (2015)                                               1.732051
# Inside Out (2015)                                           2.121320
# Mr. Holmes (2015)                                           2.000000
# '71 (2015)                                                  1.870829
# Two Days, One Night (2014)                                  1.870829
# Gett: The Trial of Viviane Amsalem (2015)                   1.870829
# Kumiko, The Treasure Hunter (2015)                          1.870829
#
#                                                  RT_norm  RT_user_norm  \
# FILM
# Avengers: Age of Ultron (2015)                  1.923538      2.073644
# Cinderella (2015)                               2.061553      2.000000
# Ant-Man (2015)                                  2.000000      2.121320
# Do You Believe? (2015)                          0.948683      2.049390
# Hot Tub Time Machine 2 (2015)                   0.836660      1.183216
# The Water Diviner (2015)                        1.774824      1.760682
# Irrational Man (2015)                           1.449138      1.627882
# Top Five (2014)                                 2.073644      1.788854
# Shaun the Sheep Movie (2015)                    2.224860      2.024846
# Love & Mercy (2015)                             2.109502      2.085665
# Far From The Madding Crowd (2015)               2.049390      1.962142
# Black Sea (2015)                                2.024846      1.732051
# Leviathan (2014)                                2.224860      1.987461
# Unbroken (2014)                                 1.596872      1.870829
# The Imitation Game (2014)                       2.121320      2.144761
# Taken 3 (2015)                                  0.670820      1.516575
# Ted 2 (2015)                                    1.516575      1.702939
# Southpaw (2015)                                 1.717556      2.000000
# Night at the Museum: Secret of the Tomb (2014)  1.581139      1.702939
# Pixels (2015)                                   0.921954      1.643168
# McFarland, USA (2015)                           1.987461      2.109502
# Insidious: Chapter 3 (2015)                     1.717556      1.673320
# The Man From U.N.C.L.E. (2015)                  1.843909      2.000000
# Run All Night (2015)                            1.732051      1.717556
# Trainwreck (2015)                               2.061553      1.923538
# Selma (2014)                                    2.224860      2.073644
# Ex Machina (2015)                               2.144761      2.073644
# Still Alice (2015)                              2.097618      2.061553
# Wild Tales (2014)                               2.190890      2.144761
# The End of the Tour (2015)                      2.144761      2.109502
# ...                                                  ...           ...
# Clouds of Sils Maria (2015)                     2.109502      1.830301
# Testament of Youth (2015)                       2.012461      1.987461
# Infinitely Polar Bear (2015)                    2.000000      1.949359
# Phoenix (2015)                                  2.224860      2.012461
# The Wolfpack (2015)                             2.049390      1.910497
# The Stanford Prison Experiment (2015)           2.049390      2.085665
# Tangerine (2015)                                2.179449      2.073644
# Magic Mike XXL (2015)                           1.760682      1.788854
# Home (2015)                                     1.500000      1.802776
# The Wedding Ringer (2015)                       1.161895      1.816590
# Woman in Gold (2015)                            1.612452      2.012461
# The Last Five Years (2015)                      1.732051      1.732051
# Mission: Impossible â€“ Rogue Nation (2015)     2.144761      2.121320
# Amy (2015)                                      2.202272      2.133073
# Jurassic World (2015)                           1.884144      2.012461
# Minions (2015)                                  1.643168      1.612452
# Max (2015)                                      1.322876      1.910497
# Paul Blart: Mall Cop 2 (2015)                   0.500000      1.341641
# The Longest Ride (2015)                         1.244990      1.910497
# The Lazarus Effect (2015)                       0.836660      1.072381
# The Woman In Black 2 Angel of Death (2015)      1.048809      1.118034
# Danny Collins (2015)                            1.962142      1.936492
# Spare Parts (2015)                              1.612452      2.037155
# Serena (2015)                                   0.948683      1.118034
# Inside Out (2015)                               2.213594      2.121320
# Mr. Holmes (2015)                               2.085665      1.974842
# '71 (2015)                                      2.202272      2.024846
# Two Days, One Night (2014)                      2.202272      1.974842
# Gett: The Trial of Viviane Amsalem (2015)       2.236068      2.012461
# Kumiko, The Treasure Hunter (2015)              2.085665      1.774824
#
#                                                 Metacritic_norm  \
# FILM
# Avengers: Age of Ultron (2015)                         1.816590
# Cinderella (2015)                                      1.830301
# Ant-Man (2015)                                         1.788854
# Do You Believe? (2015)                                 1.048809
# Hot Tub Time Machine 2 (2015)                          1.204159
# The Water Diviner (2015)                               1.581139
# Irrational Man (2015)                                  1.627882
# Top Five (2014)                                        2.012461
# Shaun the Sheep Movie (2015)                           2.012461
# Love & Mercy (2015)                                    2.000000
# Far From The Madding Crowd (2015)                      1.884144
# Black Sea (2015)                                       1.760682
# Leviathan (2014)                                       2.144761
# Unbroken (2014)                                        1.717556
# The Imitation Game (2014)                              1.910497
# Taken 3 (2015)                                         1.140175
# Ted 2 (2015)                                           1.549193
# Southpaw (2015)                                        1.688194
# Night at the Museum: Secret of the Tomb (2014)         1.532971
# Pixels (2015)                                          1.161895
# McFarland, USA (2015)                                  1.732051
# Insidious: Chapter 3 (2015)                            1.612452
# The Man From U.N.C.L.E. (2015)                         1.658312
# Run All Night (2015)                                   1.717556
# Trainwreck (2015)                                      1.936492
# Selma (2014)                                           2.109502
# Ex Machina (2015)                                      1.974842
# Still Alice (2015)                                     1.897367
# Wild Tales (2014)                                      1.962142
# The End of the Tour (2015)                             2.049390
# ...                                                         ...
# Clouds of Sils Maria (2015)                            1.974842
# Testament of Youth (2015)                              1.962142
# Infinitely Polar Bear (2015)                           1.788854
# Phoenix (2015)                                         2.133073
# The Wolfpack (2015)                                    1.936492
# The Stanford Prison Experiment (2015)                  1.843909
# Tangerine (2015)                                       2.073644
# Magic Mike XXL (2015)                                  1.732051
# Home (2015)                                            1.658312
# The Wedding Ringer (2015)                              1.322876
# Woman in Gold (2015)                                   1.596872
# The Last Five Years (2015)                             1.732051
# Mission: Impossible â€“ Rogue Nation (2015)            1.936492
# Amy (2015)                                             2.061553
# Jurassic World (2015)                                  1.717556
# Minions (2015)                                         1.673320
# Max (2015)                                             1.532971
# Paul Blart: Mall Cop 2 (2015)                          0.806226
# The Longest Ride (2015)                                1.284523
# The Lazarus Effect (2015)                              1.244990
# The Woman In Black 2 Angel of Death (2015)             1.449138
# Danny Collins (2015)                                   1.702939
# Spare Parts (2015)                                     1.581139
# Serena (2015)                                          1.341641
# Inside Out (2015)                                      2.167948
# Mr. Holmes (2015)                                      1.830301
# '71 (2015)                                             2.037155
# Two Days, One Night (2014)                             2.109502
# Gett: The Trial of Viviane Amsalem (2015)              2.121320
# Kumiko, The Treasure Hunter (2015)                     1.843909
#
#                                                 Metacritic_user_nom  \
# FILM
# Avengers: Age of Ultron (2015)                             1.884144
# Cinderella (2015)                                          1.936492
# Ant-Man (2015)                                             2.012461
# Do You Believe? (2015)                                     1.532971
# Hot Tub Time Machine 2 (2015)                              1.303840
# The Water Diviner (2015)                                   1.843909
# Irrational Man (2015)                                      1.949359
# Top Five (2014)                                            1.843909
# Shaun the Sheep Movie (2015)                               2.097618
# Love & Mercy (2015)                                        2.061553
# Far From The Madding Crowd (2015)                          1.936492
# Black Sea (2015)                                           1.816590
# Leviathan (2014)                                           1.897367
# Unbroken (2014)                                            1.802776
# The Imitation Game (2014)                                  2.024846
# Taken 3 (2015)                                             1.516575
# Ted 2 (2015)                                               1.802776
# Southpaw (2015)                                            2.024846
# Night at the Museum: Secret of the Tomb (2014)             1.702939
# Pixels (2015)                                              1.627882
# McFarland, USA (2015)                                      1.897367
# Insidious: Chapter 3 (2015)                                1.857418
# The Man From U.N.C.L.E. (2015)                             1.987461
# Run All Night (2015)                                       1.910497
# Trainwreck (2015)                                          1.732051
# Selma (2014)                                               1.884144
# Ex Machina (2015)                                          1.987461
# Still Alice (2015)                                         1.974842
# Wild Tales (2014)                                          2.097618
# The End of the Tour (2015)                                 1.936492
# ...                                                             ...
# Clouds of Sils Maria (2015)                                1.884144
# Testament of Youth (2015)                                  1.987461
# Infinitely Polar Bear (2015)                               1.987461
# Phoenix (2015)                                             2.000000
# The Wolfpack (2015)                                        1.870829
# The Stanford Prison Experiment (2015)                      2.061553
# Tangerine (2015)                                           1.910497
# Magic Mike XXL (2015)                                      1.643168
# Home (2015)                                                1.910497
# The Wedding Ringer (2015)                                  1.284523
# Woman in Gold (2015)                                       1.897367
# The Last Five Years (2015)                                 1.857418
# Mission: Impossible â€“ Rogue Nation (2015)                2.000000
# Amy (2015)                                                 2.097618
# Jurassic World (2015)                                      1.870829
# Minions (2015)                                             1.688194
# Max (2015)                                                 1.717556
# Paul Blart: Mall Cop 2 (2015)                              1.095445
# The Longest Ride (2015)                                    1.549193
# The Lazarus Effect (2015)                                  1.565248
# The Woman In Black 2 Angel of Death (2015)                 1.483240
# Danny Collins (2015)                                       1.884144
# Spare Parts (2015)                                         1.884144
# Serena (2015)                                              1.627882
# Inside Out (2015)                                          2.109502
# Mr. Holmes (2015)                                          1.987461
# '71 (2015)                                                 1.936492
# Two Days, One Night (2014)                                 2.097618
# Gett: The Trial of Viviane Amsalem (2015)                  1.910497
# Kumiko, The Treasure Hunter (2015)                         1.788854
#
#                                                 IMDB_norm  RT_norm_round  \
# FILM
# Avengers: Age of Ultron (2015)                   1.974842       1.870829
# Cinderella (2015)                                1.884144       2.121320
# Ant-Man (2015)                                   1.974842       2.000000
# Do You Believe? (2015)                           1.643168       1.000000
# Hot Tub Time Machine 2 (2015)                    1.596872       0.707107
# The Water Diviner (2015)                         1.897367       1.732051
# Irrational Man (2015)                            1.857418       1.414214
# Top Five (2014)                                  1.802776       2.121320
# Shaun the Sheep Movie (2015)                     1.923538       2.236068
# Love & Mercy (2015)                              1.974842       2.121320
# Far From The Madding Crowd (2015)                1.897367       2.000000
# Black Sea (2015)                                 1.788854       2.000000
# Leviathan (2014)                                 1.962142       2.236068
# Unbroken (2014)                                  1.897367       1.581139
# The Imitation Game (2014)                        2.012461       2.121320
# Taken 3 (2015)                                   1.746425       0.707107
# Ted 2 (2015)                                     1.816590       1.581139
# Southpaw (2015)                                  1.974842       1.732051
# Night at the Museum: Secret of the Tomb (2014)   1.774824       1.581139
# Pixels (2015)                                    1.673320       1.000000
# McFarland, USA (2015)                            1.936492       2.000000
# Insidious: Chapter 3 (2015)                      1.774824       1.732051
# The Man From U.N.C.L.E. (2015)                   1.949359       1.870829
# Run All Night (2015)                             1.816590       1.732051
# Trainwreck (2015)                                1.830301       2.121320
# Selma (2014)                                     1.936492       2.236068
# Ex Machina (2015)                                1.962142       2.121320
# Still Alice (2015)                               1.936492       2.121320
# Wild Tales (2014)                                2.024846       2.236068
# The End of the Tour (2015)                       1.987461       2.121320
# ...                                                   ...            ...
# Clouds of Sils Maria (2015)                      1.843909       2.121320
# Testament of Youth (2015)                        1.910497       2.000000
# Infinitely Polar Bear (2015)                     1.897367       2.000000
# Phoenix (2015)                                   1.897367       2.236068
# The Wolfpack (2015)                              1.884144       2.000000
# The Stanford Prison Experiment (2015)            1.884144       2.000000
# Tangerine (2015)                                 1.923538       2.236068
# Magic Mike XXL (2015)                            1.774824       1.732051
# Home (2015)                                      1.830301       1.581139
# The Wedding Ringer (2015)                        1.830301       1.224745
# Woman in Gold (2015)                             1.923538       1.581139
# The Last Five Years (2015)                       1.732051       1.732051
# Mission: Impossible â€“ Rogue Nation (2015)      1.974842       2.121320
# Amy (2015)                                       2.000000       2.236068
# Jurassic World (2015)                            1.910497       1.870829
# Minions (2015)                                   1.830301       1.581139
# Max (2015)                                       1.870829       1.414214
# Paul Blart: Mall Cop 2 (2015)                    1.466288       0.707107
# The Longest Ride (2015)                          1.897367       1.224745
# The Lazarus Effect (2015)                        1.612452       0.707107
# The Woman In Black 2 Angel of Death (2015)       1.565248       1.000000
# Danny Collins (2015)                             1.884144       2.000000
# Spare Parts (2015)                               1.897367       1.581139
# Serena (2015)                                    1.643168       1.000000
# Inside Out (2015)                                2.073644       2.236068
# Mr. Holmes (2015)                                1.923538       2.121320
# '71 (2015)                                       1.897367       2.236068
# Two Days, One Night (2014)                       1.923538       2.236068
# Gett: The Trial of Viviane Amsalem (2015)        1.974842       2.236068
# Kumiko, The Treasure Hunter (2015)               1.830301       2.121320
#
#                                                 RT_user_norm_round  \
# FILM
# Avengers: Age of Ultron (2015)                            2.121320
# Cinderella (2015)                                         2.000000
# Ant-Man (2015)                                            2.121320
# Do You Believe? (2015)                                    2.000000
# Hot Tub Time Machine 2 (2015)                             1.224745
# The Water Diviner (2015)                                  1.732051
# Irrational Man (2015)                                     1.581139
# Top Five (2014)                                           1.732051
# Shaun the Sheep Movie (2015)                              2.000000
# Love & Mercy (2015)                                       2.121320
# Far From The Madding Crowd (2015)                         2.000000
# Black Sea (2015)                                          1.732051
# Leviathan (2014)                                          2.000000
# Unbroken (2014)                                           1.870829
# The Imitation Game (2014)                                 2.121320
# Taken 3 (2015)                                            1.581139
# Ted 2 (2015)                                              1.732051
# Southpaw (2015)                                           2.000000
# Night at the Museum: Secret of the Tomb (2014)            1.732051
# Pixels (2015)                                             1.581139
# McFarland, USA (2015)                                     2.121320
# Insidious: Chapter 3 (2015)                               1.732051
# The Man From U.N.C.L.E. (2015)                            2.000000
# Run All Night (2015)                                      1.732051
# Trainwreck (2015)                                         1.870829
# Selma (2014)                                              2.121320
# Ex Machina (2015)                                         2.121320
# Still Alice (2015)                                        2.121320
# Wild Tales (2014)                                         2.121320
# The End of the Tour (2015)                                2.121320
# ...                                                            ...
# Clouds of Sils Maria (2015)                               1.870829
# Testament of Youth (2015)                                 2.000000
# Infinitely Polar Bear (2015)                              2.000000
# Phoenix (2015)                                            2.000000
# The Wolfpack (2015)                                       1.870829
# The Stanford Prison Experiment (2015)                     2.121320
# Tangerine (2015)                                          2.121320
# Magic Mike XXL (2015)                                     1.732051
# Home (2015)                                               1.870829
# The Wedding Ringer (2015)                                 1.870829
# Woman in Gold (2015)                                      2.000000
# The Last Five Years (2015)                                1.732051
# Mission: Impossible â€“ Rogue Nation (2015)               2.121320
# Amy (2015)                                                2.121320
# Jurassic World (2015)                                     2.000000
# Minions (2015)                                            1.581139
# Max (2015)                                                1.870829
# Paul Blart: Mall Cop 2 (2015)                             1.414214
# The Longest Ride (2015)                                   1.870829
# The Lazarus Effect (2015)                                 1.000000
# The Woman In Black 2 Angel of Death (2015)                1.224745
# Danny Collins (2015)                                      2.000000
# Spare Parts (2015)                                        2.000000
# Serena (2015)                                             1.224745
# Inside Out (2015)                                         2.121320
# Mr. Holmes (2015)                                         2.000000
# '71 (2015)                                                2.000000
# Two Days, One Night (2014)                                2.000000
# Gett: The Trial of Viviane Amsalem (2015)                 2.000000
# Kumiko, The Treasure Hunter (2015)                        1.732051
#
#                                                 Metacritic_norm_round  \
# FILM
# Avengers: Age of Ultron (2015)                               1.870829
# Cinderella (2015)                                            1.870829
# Ant-Man (2015)                                               1.732051
# Do You Believe? (2015)                                       1.000000
# Hot Tub Time Machine 2 (2015)                                1.224745
# The Water Diviner (2015)                                     1.581139
# Irrational Man (2015)                                        1.581139
# Top Five (2014)                                              2.000000
# Shaun the Sheep Movie (2015)                                 2.000000
# Love & Mercy (2015)                                          2.000000
# Far From The Madding Crowd (2015)                            1.870829
# Black Sea (2015)                                             1.732051
# Leviathan (2014)                                             2.121320
# Unbroken (2014)                                              1.732051
# The Imitation Game (2014)                                    1.870829
# Taken 3 (2015)                                               1.224745
# Ted 2 (2015)                                                 1.581139
# Southpaw (2015)                                              1.732051
# Night at the Museum: Secret of the Tomb (2014)               1.581139
# Pixels (2015)                                                1.224745
# McFarland, USA (2015)                                        1.732051
# Insidious: Chapter 3 (2015)                                  1.581139
# The Man From U.N.C.L.E. (2015)                               1.732051
# Run All Night (2015)                                         1.732051
# Trainwreck (2015)                                            2.000000
# Selma (2014)                                                 2.121320
# Ex Machina (2015)                                            2.000000
# Still Alice (2015)                                           1.870829
# Wild Tales (2014)                                            2.000000
# The End of the Tour (2015)                                   2.000000
# ...                                                               ...
# Clouds of Sils Maria (2015)                                  2.000000
# Testament of Youth (2015)                                    2.000000
# Infinitely Polar Bear (2015)                                 1.732051
# Phoenix (2015)                                               2.121320
# The Wolfpack (2015)                                          2.000000
# The Stanford Prison Experiment (2015)                        1.870829
# Tangerine (2015)                                             2.121320
# Magic Mike XXL (2015)                                        1.732051
# Home (2015)                                                  1.732051
# The Wedding Ringer (2015)                                    1.414214
# Woman in Gold (2015)                                         1.581139
# The Last Five Years (2015)                                   1.732051
# Mission: Impossible â€“ Rogue Nation (2015)                  2.000000
# Amy (2015)                                                   2.121320
# Jurassic World (2015)                                        1.732051
# Minions (2015)                                               1.732051
# Max (2015)                                                   1.581139
# Paul Blart: Mall Cop 2 (2015)                                0.707107
# The Longest Ride (2015)                                      1.224745
# The Lazarus Effect (2015)                                    1.224745
# The Woman In Black 2 Angel of Death (2015)                   1.414214
# Danny Collins (2015)                                         1.732051
# Spare Parts (2015)                                           1.581139
# Serena (2015)                                                1.414214
# Inside Out (2015)                                            2.121320
# Mr. Holmes (2015)                                            1.870829
# '71 (2015)                                                   2.000000
# Two Days, One Night (2014)                                   2.121320
# Gett: The Trial of Viviane Amsalem (2015)                    2.121320
# Kumiko, The Treasure Hunter (2015)                           1.870829
#
#                                                 Metacritic_user_norm_round  \
# FILM
# Avengers: Age of Ultron (2015)                                    1.870829
# Cinderella (2015)                                                 2.000000
# Ant-Man (2015)                                                    2.000000
# Do You Believe? (2015)                                            1.581139
# Hot Tub Time Machine 2 (2015)                                     1.224745
# The Water Diviner (2015)                                          1.870829
# Irrational Man (2015)                                             2.000000
# Top Five (2014)                                                   1.870829
# Shaun the Sheep Movie (2015)                                      2.121320
# Love & Mercy (2015)                                               2.121320
# Far From The Madding Crowd (2015)                                 2.000000
# Black Sea (2015)                                                  1.870829
# Leviathan (2014)                                                  1.870829
# Unbroken (2014)                                                   1.870829
# The Imitation Game (2014)                                         2.000000
# Taken 3 (2015)                                                    1.581139
# Ted 2 (2015)                                                      1.870829
# Southpaw (2015)                                                   2.000000
# Night at the Museum: Secret of the Tomb (2014)                    1.732051
# Pixels (2015)                                                     1.581139
# McFarland, USA (2015)                                             1.870829
# Insidious: Chapter 3 (2015)                                       1.870829
# The Man From U.N.C.L.E. (2015)                                    2.000000
# Run All Night (2015)                                              1.870829
# Trainwreck (2015)                                                 1.732051
# Selma (2014)                                                      1.870829
# Ex Machina (2015)                                                 2.000000
# Still Alice (2015)                                                2.000000
# Wild Tales (2014)                                                 2.121320
# The End of the Tour (2015)                                        2.000000
# ...                                                                    ...
# Clouds of Sils Maria (2015)                                       1.870829
# Testament of Youth (2015)                                         2.000000
# Infinitely Polar Bear (2015)                                      2.000000
# Phoenix (2015)                                                    2.000000
# The Wolfpack (2015)                                               1.870829
# The Stanford Prison Experiment (2015)                             2.121320
# Tangerine (2015)                                                  1.870829
# Magic Mike XXL (2015)                                             1.581139
# Home (2015)                                                       1.870829
# The Wedding Ringer (2015)                                         1.224745
# Woman in Gold (2015)                                              1.870829
# The Last Five Years (2015)                                        1.870829
# Mission: Impossible â€“ Rogue Nation (2015)                       2.000000
# Amy (2015)                                                        2.121320
# Jurassic World (2015)                                             1.870829
# Minions (2015)                                                    1.732051
# Max (2015)                                                        1.732051
# Paul Blart: Mall Cop 2 (2015)                                     1.000000
# The Longest Ride (2015)                                           1.581139
# The Lazarus Effect (2015)                                         1.581139
# The Woman In Black 2 Angel of Death (2015)                        1.414214
# Danny Collins (2015)                                              1.870829
# Spare Parts (2015)                                                1.870829
# Serena (2015)                                                     1.581139
# Inside Out (2015)                                                 2.121320
# Mr. Holmes (2015)                                                 2.000000
# '71 (2015)                                                        2.000000
# Two Days, One Night (2014)                                        2.121320
# Gett: The Trial of Viviane Amsalem (2015)                         1.870829
# Kumiko, The Treasure Hunter (2015)                                1.732051
#
#                                                 IMDB_norm_round  \
# FILM
# Avengers: Age of Ultron (2015)                         2.000000
# Cinderella (2015)                                      1.870829
# Ant-Man (2015)                                         2.000000
# Do You Believe? (2015)                                 1.581139
# Hot Tub Time Machine 2 (2015)                          1.581139
# The Water Diviner (2015)                               1.870829
# Irrational Man (2015)                                  1.870829
# Top Five (2014)                                        1.870829
# Shaun the Sheep Movie (2015)                           1.870829
# Love & Mercy (2015)                                    2.000000
# Far From The Madding Crowd (2015)                      1.870829
# Black Sea (2015)                                       1.732051
# Leviathan (2014)                                       2.000000
# Unbroken (2014)                                        1.870829
# The Imitation Game (2014)                              2.000000
# Taken 3 (2015)                                         1.732051
# Ted 2 (2015)                                           1.870829
# Southpaw (2015)                                        2.000000
# Night at the Museum: Secret of the Tomb (2014)         1.732051
# Pixels (2015)                                          1.732051
# McFarland, USA (2015)                                  2.000000
# Insidious: Chapter 3 (2015)                            1.732051
# The Man From U.N.C.L.E. (2015)                         2.000000
# Run All Night (2015)                                   1.870829
# Trainwreck (2015)                                      1.870829
# Selma (2014)                                           2.000000
# Ex Machina (2015)                                      2.000000
# Still Alice (2015)                                     2.000000
# Wild Tales (2014)                                      2.000000
# The End of the Tour (2015)                             2.000000
# ...                                                         ...
# Clouds of Sils Maria (2015)                            1.870829
# Testament of Youth (2015)                              1.870829
# Infinitely Polar Bear (2015)                           1.870829
# Phoenix (2015)                                         1.870829
# The Wolfpack (2015)                                    1.870829
# The Stanford Prison Experiment (2015)                  1.870829
# Tangerine (2015)                                       1.870829
# Magic Mike XXL (2015)                                  1.732051
# Home (2015)                                            1.870829
# The Wedding Ringer (2015)                              1.870829
# Woman in Gold (2015)                                   1.870829
# The Last Five Years (2015)                             1.732051
# Mission: Impossible â€“ Rogue Nation (2015)            2.000000
# Amy (2015)                                             2.000000
# Jurassic World (2015)                                  1.870829
# Minions (2015)                                         1.870829
# Max (2015)                                             1.870829
# Paul Blart: Mall Cop 2 (2015)                          1.414214
# The Longest Ride (2015)                                1.870829
# The Lazarus Effect (2015)                              1.581139
# The Woman In Black 2 Angel of Death (2015)             1.581139
# Danny Collins (2015)                                   1.870829
# Spare Parts (2015)                                     1.870829
# Serena (2015)                                          1.581139
# Inside Out (2015)                                      2.121320
# Mr. Holmes (2015)                                      1.870829
# '71 (2015)                                             1.870829
# Two Days, One Night (2014)                             1.870829
# Gett: The Trial of Viviane Amsalem (2015)              2.000000
# Kumiko, The Treasure Hunter (2015)                     1.870829
#
#                                                 Fandango_Difference
# FILM
# Avengers: Age of Ultron (2015)                             0.707107
# Cinderella (2015)                                          0.707107
# Ant-Man (2015)                                             0.707107
# Do You Believe? (2015)                                     0.707107
# Hot Tub Time Machine 2 (2015)                              0.707107
# The Water Diviner (2015)                                   0.707107
# Irrational Man (2015)                                      0.707107
# Top Five (2014)                                            0.707107
# Shaun the Sheep Movie (2015)                               0.707107
# Love & Mercy (2015)                                        0.707107
# Far From The Madding Crowd (2015)                          0.707107
# Black Sea (2015)                                           0.707107
# Leviathan (2014)                                           0.707107
# Unbroken (2014)                                            0.632456
# The Imitation Game (2014)                                  0.632456
# Taken 3 (2015)                                             0.632456
# Ted 2 (2015)                                               0.632456
# Southpaw (2015)                                            0.632456
# Night at the Museum: Secret of the Tomb (2014)             0.632456
# Pixels (2015)                                              0.632456
# McFarland, USA (2015)                                      0.632456
# Insidious: Chapter 3 (2015)                                0.632456
# The Man From U.N.C.L.E. (2015)                             0.632456
# Run All Night (2015)                                       0.632456
# Trainwreck (2015)                                          0.632456
# Selma (2014)                                               0.632456
# Ex Machina (2015)                                          0.632456
# Still Alice (2015)                                         0.632456
# Wild Tales (2014)                                          0.632456
# The End of the Tour (2015)                                 0.632456
# ...                                                             ...
# Clouds of Sils Maria (2015)                                0.316228
# Testament of Youth (2015)                                  0.316228
# Infinitely Polar Bear (2015)                               0.316228
# Phoenix (2015)                                             0.316228
# The Wolfpack (2015)                                        0.316228
# The Stanford Prison Experiment (2015)                      0.316228
# Tangerine (2015)                                           0.316228
# Magic Mike XXL (2015)                                      0.316228
# Home (2015)                                                0.316228
# The Wedding Ringer (2015)                                  0.316228
# Woman in Gold (2015)                                       0.316228
# The Last Five Years (2015)                                 0.316228
# Mission: Impossible â€“ Rogue Nation (2015)                0.316228
# Amy (2015)                                                 0.316228
# Jurassic World (2015)                                      0.000000
# Minions (2015)                                             0.000000
# Max (2015)                                                 0.000000
# Paul Blart: Mall Cop 2 (2015)                              0.000000
# The Longest Ride (2015)                                    0.000000
# The Lazarus Effect (2015)                                  0.000000
# The Woman In Black 2 Angel of Death (2015)                 0.000000
# Danny Collins (2015)                                       0.000000
# Spare Parts (2015)                                         0.000000
# Serena (2015)                                              0.000000
# Inside Out (2015)                                          0.000000
# Mr. Holmes (2015)                                          0.000000
# '71 (2015)                                                 0.000000
# Two Days, One Night (2014)                                 0.000000
# Gett: The Trial of Viviane Amsalem (2015)                  0.000000
# Kumiko, The Treasure Hunter (2015)                         0.000000
#
# [146 rows x 15 columns]

# %% [markdown]
# ### Lambda function
# In the code above, we passed a lambda function to the DataFrame.apply() method. A **lambda function** is also called an *anonymous function*, because we aren't defining a new, named function (e.g. a function called double()) and then using it. The lambda function `x*2` only **lives for the life of the DataFrame.apply() method call**. A lambda function consists of 2 parts:
# * a variable name, that we can refer to in our transformation logic: lambda x:
# * the transformation logic: x*2 (multiply by 2)
#
# The function / method has to work with series (**vectorised**)!, e.g. `math.sqrt(x)` doesn't work, but `numpy.sqrt(x)` does.

# %%
halved_df = float_df.apply(lambda x: x/2)
#print(halved_df.head(5))

# Applying lambda function to rows

# select relevant columns
rt_mt_user = float_df[['RT_user_norm', 'Metacritic_user_nom']]

#get standard deviation across rows
std = rt_mt_user.apply(lambda x: np.std(x), axis=1)
print(std.head(5))

#get mean rating of certain columns
columns = float_df[['RT_user_norm', 'Metacritic_user_nom']]
rt_mt_means = columns.apply(lambda x: np.mean(x), axis = 1)
print(rt_mt_means.head(5))
# Out:
# FILM
# Avengers: Age of Ultron (2015)    0.375
# Cinderella (2015)                 0.125
# Ant-Man (2015)                    0.225
# Do You Believe? (2015)            0.925
# Hot Tub Time Machine 2 (2015)     0.150
# dtype: float64
# FILM
# Avengers: Age of Ultron (2015)    3.925
# Cinderella (2015)                 3.875
# Ant-Man (2015)                    4.275
# Do You Believe? (2015)            3.275
# Hot Tub Time Machine 2 (2015)     1.550
# dtype: float64
